# %%
import pandas as pd

# %%
df = pd.read_json("/Users/clairezhang/Desktop/Data_Bootcamp/Yelp_Project/Data/yelp_academic_dataset_business.json",
                 lines = True)

# %%
df.head()
# Out:
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 4         4827 E Downing Cir             Mesa    AZ       85205  33.428065
#
#     longitude  stars  review_count  is_open  \
# 0  -80.852612    3.5            36        1
# 1 -111.890264    5.0             4        1
# 2  -73.580070    5.0             5        1
# ...

# %%
df_clean = df.drop(columns = ['business_id', 'latitude', 'longitude', 'attributes', 'hours'])
df_clean
# Out:
#                              name                          address  \
# 0        The Range At Lake Norman                  10913 Bailey Rd
# 1               Carlos Santo, NMD        8880 E Via Linda, Ste 107
# 2                         Felinus            3554 Rue Notre-Dame O
# 3            Nevada House of Hose                   1015 Sharp Cir
# 4         USE MY GUY SERVICES LLC               4827 E Downing Cir
# ...                           ...                              ...
# 209388                Nishi Sushi                 9750 Weston Road
# 209389                    Walmart              3240 Wilkinson Blvd
# 209390                  Five Guys          7014-590 E Camelback Rd
# 209391  Indian Trail Dog Training
# 209392                  Kudlow Ye  21 St Clair Avenue E, Suite 401
#
#                    city state postal_code  stars  review_count  is_open  \
# 0             Cornelius    NC       28031    3.5            36        1
# ...

# %%
df_open = df_clean.drop(df_clean[df_clean['is_open'] == 0].index)
df_open
# Out:
#                                name                          address  \
# 0          The Range At Lake Norman                  10913 Bailey Rd
# 1                 Carlos Santo, NMD        8880 E Via Linda, Ste 107
# 2                           Felinus            3554 Rue Notre-Dame O
# 4           USE MY GUY SERVICES LLC               4827 E Downing Cir
# 5       Oasis Auto Center - Gilbert        1720 W Elliot Rd, Ste 105
# ...                             ...                              ...
# 209386            Water Heater Pros
# 209387                         Aldo              6455 Macleod Trl SW
# 209390                    Five Guys          7014-590 E Camelback Rd
# 209391    Indian Trail Dog Training
# 209392                    Kudlow Ye  21 St Clair Avenue E, Suite 401
#
#                 city state postal_code  stars  review_count  is_open  \
# 0          Cornelius    NC       28031    3.5            36        1
# ...

# %%
fitness = ['Fitness', 'Cycling']

# %%
df_fit = df_open[df_open['categories'].str.contains("Fitness | Cycling", na = False)]
df_fit
# Out:
#                                        name  \
# 1                         Carlos Santo, NMD
# 9                            Xtreme Couture
# 19               Gateway Fit Body Boot Camp
# 56                               LA Fitness
# 177                          Fitness Nation
# ...                                     ...
# 209140     Rocky River Golf Club At Concord
# 209257              Family ATA Martial Arts
# 209261              Cleveland Salsa Passion
# 209289           Gracie Barra North Phoenix
# 209302  Kristin Sunderhaft Golf Instruction
#
#                                   address         city state postal_code  \
# 1               8880 E Via Linda, Ste 107   Scottsdale    AZ       85258
# 9            700 Kipling Avenue Etobicoke      Toronto    ON     M8Z 5G3
# 19                        5229 S Power Rd         Mesa    AZ       85212
# 56                       7640 W Thomas Rd      Phoenix    AZ       85033
# ...

# %%
df_fit.to_csv("/Users/clairezhang/Desktop/Data_Bootcamp/Yelp_Project/Data/yelp_academic_dataset_business_clean.csv")
