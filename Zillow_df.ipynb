# %%
import pandas as pd

# %%
# rent
url_zil = "https://github.com/kriwang27/PythonProjs/raw/main/zillow_dataset_2015onwards"
df1 = pd.read_csv(url_zil)

df1.head()
# Out:
#    SizeRank  RegionName State      City  1/31/2015  2/28/2015  3/31/2015  \
# 0         0       10025    NY  New York  1284107.0  1288022.0  1291641.0
# 1         1       60657    IL   Chicago   455544.0   454995.0   455591.0
# 2         2       10023    NY  New York  1114768.0  1119061.0  1122156.0
# 3         3       77494    TX      Katy   329686.0   331322.0   331948.0
# 4         4       60614    IL   Chicago   595063.0   595289.0   596813.0
#
#    4/30/2015  5/31/2015  6/30/2015  ...  3/31/2019  4/30/2019  5/31/2019  \
# 0  1297435.0  1301773.0  1310252.0  ...    1414364    1402789    1397035
# 1   458332.0   461017.0   461423.0  ...     490741     490541     491009
# 2  1126959.0  1128140.0  1135103.0  ...    1116064    1108286    1107903
# 3   333331.0   334973.0   336566.0  ...     335636     334839     334252
# 4   601725.0   606225.0   607410.0  ...     644743     645662     645999
#
#    6/30/2019  7/31/2019  8/31/2019  9/30/2019  10/31/2019  11/30/2019  \
# ...
